# %% [markdown]
# Projet Netflix

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("./file.csv")
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head(10) # Afficher les 5 prmières lignes par défaut de la base
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.tail()# Afficher les 5 dernières lignes de la BDD ( fction contraire de la commande head)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape # Afficher le nbre des lignes et colonnes de la BDD
# Out:
# (7789, 11)

# %%
df.size # Permet d'afficher le nbre d'éléments de la BDD
# Out:
# 85679

# %%
df.columns # Affiche les noms de chaque colonnes
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df["Title"] # Permet d'afficher les éléments d'une colonne
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7789, dtype: object

# %%
df.dtypes # Afficher le types des variables
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info() # Afficher l'ensmble des infos des varaibles de la BDD
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.duplicated() # Afficher s'il existe vrai ou faux des lignes qui se repètent dans la BDD
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
df[df.duplicated()] Afficher exactement les lignes dupliquées( répétées)
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
position=df[df.duplicated()].index # Afficher la position des lignes dupliquées
position
# Out:
# Index([6300, 6622], dtype='int64')

# %%
data=df.drop_duplicates() # Supprimer les lignes dupliqées dans la BDD puis considérer une nouvelle BDD(data)
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.isnull() # Afficher oui ou non s'il existe les valeurs manquantes des variables
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum() # Afficher la somme des valeurs manquantes des variables
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull()) # Créer une carte thermique qui visualiser les valeurs manquantes de la BDD
# Out:
# <Axes: >

# %%
data[data["Title"].isin(["House of Cards"])] # Afficher toute les infos de la ligne où se trouve la modalité "House of Cards"  dans la variable title de notre BDD
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data["Title"].str.contains("House of Cards")] # Même rôle que isin
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data["Date_N"]= pd.to_datetime(data["Release_Date"], errors='coerce') # Convertir les chains des caractères  représentants les dates en format réel
data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\3898849326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date_N"]= pd.to_datetime(data["Release_Date"], errors='coerce') # Convertir les chains des caractères  représentants les dates en format réel
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# ...

# %%
data["Date_N"].dt.year.value_counts() # Affiche le nombre des dates de réalisations des titres(fims) par année
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data["Date_N"].dt.year.value_counts().plot(kind="bar", ylabel="Nombre des dates de Réalisation",
                                          xlabel="Année", color= "green", title ="Répartition du nombre des dates de réalisations des titres par année")
# Out:
# <Axes: title={'center': 'Répartition du nombre des dates de réalisations des titres par année'}, xlabel='Année', ylabel='Nombre des dates de Réalisation'>

# %%
data["Category"].unique() # Afficher les différentes modalités d'une variable
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
data["Category"].value_counts() # Afficher le nbre des valeurs de chaque modalité d'une variable
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
data.groupby("Category").Category.count() # Deuxième méthode pour compter les modalités d'une variable
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x="Category", data=data, palette={"Movie": "blue", "TV Show": "purple"})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\2199292747.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Category", data=data, palette={"Movie": "blue", "TV Show": "purple"})
# <Axes: xlabel='Category', ylabel='count'>

# %%
data["Year"]= data["Date_N"].dt.year # Création d'une nouvelle colonne(Year) en extrayant l'année dans la variable Date_N
data.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\2850789069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Year"]= data["Date_N"].dt.year # Création d'une nouvelle colonne(Year) en extrayant l'année dans la variable Date_N
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# ...

# %%
data[(data["Category"]== 'Movie') & (data["Year"]== 2020)] # On veut connaitre uniquement le nbre de Films réalisés en 2020
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
data[(data["Category"] == 'TV Show') & (data["Country"] == 'India')]["Title"] # Connaître les titres de série produit en Inde
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
data["Month"]= data["Date_N"].dt.month # Création d'une nouvelle colonne(Month) en extrayant les mois dans la variable Date_N
data.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\3354179865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Month"]= data["Date_N"].dt.month # Création d'une nouvelle colonne(Year) en extrayant l'année dans la variable Date_N
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# ...

# %%
data["Director"].value_counts().head(10) # Afficher les 10 meilleurs réalisateurs qui ont plus grands nombres d'émissions
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Comedies")][data["Country"]=="United Kingdom"] # Connaitre le type de films comediens du royaum Uni
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\2341997879.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[(data["Category"]=="Movie") & (data["Type"]=="Comedies")][data["Country"]=="United Kingdom"] # Connaitre le type de films comediens du royaum Uni
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# ...

# %%
dw=data.dropna() # Supprimer les valeurs manquantes et création d'une nouvelle BBD
dw
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
dw[dw["Cast"].str.contains("Tom Cruise")] # Nombre de séries/films que Tom a-t-il joué
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year  \
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0
#
#       Month
# 3860    1.0
# 5071    7.0

# %%
dw["Rating"].nunique() # nombre total des modalités d'une variable
# Out:
# 14

# %%
dw["Rating"].value_counts() # Les effectifs de chaque modalité
# Out:
# Rating
# TV-MA       1666
# TV-14       1132
# R            654
# TV-PG        410
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: count, dtype: int64

# %%
dw[(dw["Category"]=="Movie") & (dw["Rating"]=="TV-14")][dw["Country"]=="Canada"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\2405607620.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dw[(dw["Category"]=="Movie") & (dw["Rating"]=="TV-14")][dw["Country"]=="Canada"]
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# ...

# %%
dw[(dw["Category"]=="Movie") & (dw["Rating"]=="TV-14") & (dw["Country"]=="Canada")] # 2ème méthode
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %%
dw[(dw["Category"]=="TV Show") & (dw["Rating"]=="R")][dw["Year"]>2019] # Connaître le nombre de séries ont été joué après 2018?
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\1702140129.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dw[(dw["Category"]=="TV Show") & (dw["Rating"]=="R")][dw["Year"]>2019]
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year, Month]
# Index: []

# %%
data[["Minutes", "Unit"]] = data["Duration"].str.split(" ", expand=True) # Nouvelle variable(minutes et unité) qui définit la durée des films ou séries
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\3290880959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minutes", "Unit"]] = data["Duration"].str.split(" ", expand=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_1308\3290880959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Minutes", "Unit"]] = data["Duration"].str.split(" ", expand=True)

# %%
data["Minutes"].max() # Minutes maximal
# Out:
# '99'

# %%
dataTV=data[data["Category"]=="TV Show"] # Variable TV Show
dataTV
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
dataTV.Country.value_counts() # Pays ayant un nombre élevé des séries
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data.sort_values(by="Year", ascending=False).head() # Trier les années par ordre décroissant
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5955   s5955    Movie                                   Taare Zameen Par
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 1355               Chris Rock
# 5955               Aamir Khan
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 1355                                         Chris Rock
# ...

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Dramas")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data["Category"]=="TV Show") & (data["Type"]=="Kids TV")]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year, Month, Minutes, Unit]
# Index: []
